# %%
senetence = """
Natural language processing (NLP) is the processing of natural language information by a computer. NLP is a subfield of computer science and is closely associated with artificial intelligence. NLP is also related to information retrieval, knowledge representation, computational linguistics, and linguistics more broadly.
"""

# %%
import nltk

print(nltk.__version__)
print(hasattr(nltk, "download"))
print(hasattr(nltk, "internals"))
# Out:
# 3.9.4
# True
# False

# %%
from nltk.downloader import Downloader

d = Downloader()
d.download('punkt')
d.download('punkt_tab')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 from nltk.downloader import Downloader
#       2
#       3 d = Downloader()
# ----> 4 d.download('punkt')
#       5 d.download('punkt_tab')
#
# File c:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\nltk\downloader.py:786, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     777 def show(s, prefix2=""):
#     778     print_to(
#     779         textwrap.fill(
#     780             s,
#    (...)    783         )
#     784     )
# --> 786 for msg in self.incr_download(info_or_id, download_dir, force):
#     787     # Error messages
#     788     if isinstance(msg, ErrorMessage):
#     789         show(msg.message)
#
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize

text = "Hello world. How are you?"
print(sent_tokenize(text))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[13], line 5
#       1 import nltk
#       2 from nltk.tokenize import sent_tokenize
#       3
#       4 text = "Hello world. How are you?"
# ----> 5 print(sent_tokenize(text))
#
# File c:\Users\hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# ...
