# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\hp\Desktop\NLP\uk_pm.csv")
dataset.head(2)
# Out:
#                     id                                               text  \
# 0  1584696134693711873  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  1584696057841098752  #RishiSunak is the richest Tory MP in history....
#
#       username                                           hashtags  \
# 0  IsmailYSyed  ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1   AdameMedia                                     ['RishiSunak']
#
#                   created_at  user followers count  replycount  retweetcount  \
# 0  2022-10-24 23:59:35+00:00                   393           0             0
# 1  2022-10-24 23:59:17+00:00                  9830           3            23
#
#    likecount  quotecount language  quotedtweet  inReplyToTweetId  \
# 0          0           0       en          NaN      1.584541e+18
# 1         68           4       en          NaN               NaN
#
#                          inReplyToUser  \
# 0  https://twitter.com/BritIndianVoice
# ...

# %%
# Dropping non imp features:    
dataset.drop(columns = ["id", "username", "created_at", "user followers count", "replycount", "retweetcount", "likecount", "quotecount", "quotedtweet", "inReplyToTweetId", "inReplyToUser", "language", "hashtags", "mentionedUsers"], inplace = True)

# %%
dataset["text"] = dataset["text"].str.lower()

# %%
dataset["text"] = dataset["text"].str.replace(r"[^a-zA-Z0-9\s]", "", regex=True)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tokenizer = AutoTokenizer("nlptown/bert-base-multilingual-uncased-sentiment")
#
# TypeError: AutoTokenizer.__init__() takes 1 positional argument but 2 were given
